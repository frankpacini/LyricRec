# %%
import requests

session = requests.Session()
session.headers = {
    'application': 'LyricRec',
    'User-Agent': 'https://github.com/frankpacini/LyricRec'
}

access_token = 'Bearer ' + open("token2.txt", "r").read()
authorization_header = {'Authorization': access_token}

def getArtistId(artist_name):
    search_response = session.request('GET', 'https://api.genius.com/search', params={'q': artist_name, "per_page": 20}, headers=authorization_header)
    
    for i in range(50):
        search_result = search_response.json()['response']['hits'][i]['result']['primary_artist']
        search_result_name = search_result['name'].replace(u'\u200b', '')
        if search_result_name == artist_name:
            return search_result['id']
        else:
            print("    Incorrect artist name '{}', expected '{}'".format(search_result_name, artist_name))
    return -1

def getArtistSongs(artist_name, artist_id=None):
    if artist_id is None:
        artist_id = getArtistId(artist_name)
    uri = 'https://api.genius.com/artists/{}/songs'.format(artist_id)
    next_page = 1
    songs = []
    while next_page:
        params = {'sort': 'popularity', 'per_page': 50, 'page': next_page}
        response = session.request('GET', uri, params=params, headers=authorization_header)
        try:
            next_page = response.json()['response']['next_page']
        except KeyError:
            print(response.json())
        
        for song in response.json()['response']['songs']:
            if song['primary_artist']['name'] != artist_name or song['lyrics_state'] != 'complete':
                continue
            if 'pageviews' not in song['stats']:
                next_page = None
                break
            songs.append([song['id'], song['title'], artist_name, song['stats']['pageviews'], song['pyongs_count'], song['annotation_count']])
    return songs

# %%
with open("artists.txt", encoding="utf-8") as file:
    artists = {line.rstrip() for line in file.readlines()}
artists = list(artists)

# %%
ids = []
for artist in artists:
    print(artist)
    ids.append(getArtistId(artist))
artists += ['Prince', 'R.E.M.']
ids += [660, 8243]
# Out:
# Radiohead
# Barbra Streisand
# Bee Gees
# Nirvana
# Sly and the Family Stone
# The Temptations
# JAY-Z
# Fleetwood Mac
# Arcade Fire
# King Crimson
# Eagles
# Swans
# Simon & Garfunkel
# Chris Brown
# Taylor Swift
# Marvin Gaye
#     Incorrect artist name 'Charlie Puth', expected 'Marvin Gaye'
# Otis Redding
# Madvillain
# James Brown
# Eminem
# Madonna
#     Incorrect artist name 'Drake', expected 'Madonna'
# Céline Dion
# MF DOOM
#     Incorrect artist name 'Madvillain', expected 'MF DOOM'
# Animal Collective
# Linkin Park
# The Band
# Katy Perry
# Al Green
# The Clash
# Mariah Carey
# Lou Reed
# Patti Smith
#     Incorrect artist name 'Patti Smith Group', expected 'Patti Smith'
# Chuck Berry
# Nick Drake
# Buddy Holly
#     Incorrect artist name 'Weezer', expected 'Buddy Holly'
# Led Zeppelin
# Stevie Wonder
# Billy Joel
# Björk
# Van Morrison
# Neil Young
# Joy Division
# The Doors
# Metallica
# Kate Bush
# Tina Turner
#     Incorrect artist name 'Ike & Tina Turner', expected 'Tina Turner'
# Tool
# The Who
# Death Grips
# The Jimi Hendrix Experience
# OutKast
# Bruno Mars
# Elvis Presley
# Oasis
# The Rolling Stones
# U2
# Nick Cave & The Bad Seeds
# Johnny Cash
# Aerosmith
# Ray Charles
# Eric Clapton
# A Tribe Called Quest
# Maroon 5
# Frank Zappa
# Whitney Houston
# Curtis Mayfield
# Pink Floyd
# The Police
# Beastie Boys
# The Beatles
# James Taylor
#     Incorrect artist name 'James TW', expected 'James Taylor'
# The Byrds
# Black Sabbath
# Queen
# Adele
# my bloody valentine
# Coldplay
#     Incorrect artist name 'The Chainsmokers & Coldplay', expected 'Coldplay'
# Joni Mitchell
# Lady Gaga
#     Incorrect artist name 'Lady Gaga & Bradley Cooper', expected 'Lady Gaga'
# The Velvet Underground
# Rihanna
# The Cure
#     Incorrect artist name 'Lady Gaga', expected 'The Cure'
# Lil Wayne
# Aretha Franklin
# Sam Cooke
# The Microphones
# The Kinks
# The Stooges
# Frank Sinatra
# Justin Bieber
# Kendrick Lamar
# Wu-Tang Clan
# 2Pac
# David Bowie
#     Incorrect artist name 'Queen & David Bowie', expected 'David Bowie'
# PJ Harvey
# Phil Collins
# Bruce Springsteen
# Ed Sheeran
# Bob Marley
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
#     Incorrect artist name 'Dadju', expected 'Bob Marley'
#     Incorrect artist name 'Bob Marley & The Wailers', expected 'Bob Marley'
# Santana
# Massive Attack
# Iron Maiden
# Tom Waits
# ABBA
# Frank Ocean
# Guns N’ Roses
# Kanye West
# Modest Mouse
# Ramones
# Portishead
# Red Hot Chili Peppers
# Little Richard
# Sonic Youth
# Elton John
# Creedence Clearwater Revival
# Beyoncé
# Steely Dan
# Elvis Costello
# The Four Tops
# Justin Timberlake
# Britney Spears
# Donna Summer
# Bob Dylan
# Wilco
#     Incorrect artist name 'André De Shields, Reeve Carney, Jewelle Blackman, Yvette Gonzalez-Nacer, Kay Trinidad, Timothy Hughes, Malcolm Armwood, Jessie Shelton, Kimberly Marable, Khaila Wilcoxon, Ahmad Simmons, Afra Hines, T. Oliver Reid & John Krause', expected 'Wilco'
# Ween
# Alice in Chains
# Bon Jovi
# The Smiths
# AC/DC
# Nicki Minaj
#     Incorrect artist name 'Migos, Nicki Minaj & Cardi B', expected 'Nicki Minaj'
# The Beach Boys
# Elliott Smith
# Beck
#     Incorrect artist name 'Russ Millions & Tion Wayne', expected 'Beck'
# Nine Inch Nails
# Sufjan Stevens
# Public Enemy
# Talking Heads
# New Order
# Michael Jackson
# Janis Joplin
# Drake

# %%
import pandas as pd
pd.DataFrame({'Artist': artists, 'Id': ids}).to_csv("artists.csv")

# %%
artist_df = pd.read_csv("artists.csv")
songs = []
for _,row in artist_df.iterrows():
    print(row['Artist'])
    songs += getArtistSongs(row['Artist'], row['Id'])
# Out:
# Radiohead
# Barbra Streisand
# Bee Gees
# Nirvana
# Sly and the Family Stone
# The Temptations
# JAY-Z
# Fleetwood Mac
# Arcade Fire
# King Crimson
# Eagles
# Swans
# Simon & Garfunkel
# Chris Brown
# Taylor Swift
# Marvin Gaye
# Otis Redding
# Madvillain
# James Brown
# Eminem
# Madonna
# Céline Dion
# MF DOOM
# Animal Collective
# Linkin Park
# The Band
# Katy Perry
# Al Green
# The Clash
# Mariah Carey
# Lou Reed
# Patti Smith
# Chuck Berry
# Nick Drake
# Buddy Holly
# Led Zeppelin
# Stevie Wonder
# Billy Joel
# Björk
# Van Morrison
# Neil Young
# Joy Division
# The Doors
# Metallica
# Kate Bush
# Tina Turner
# Tool
# The Who
# Death Grips
# The Jimi Hendrix Experience
# OutKast
# Bruno Mars
# Elvis Presley
# Oasis
# The Rolling Stones
# U2
# Nick Cave & The Bad Seeds
# Johnny Cash
# Aerosmith
# Ray Charles
# Eric Clapton
# A Tribe Called Quest
# Maroon 5
# Frank Zappa
# Whitney Houston
# Curtis Mayfield
# Pink Floyd
# The Police
# Beastie Boys
# The Beatles
# James Taylor
# The Byrds
# Black Sabbath
# Queen
# Adele
# my bloody valentine
# Coldplay
# Joni Mitchell
# Lady Gaga
# The Velvet Underground
# Rihanna
# The Cure
# Lil Wayne
# Aretha Franklin
# Sam Cooke
# The Microphones
# The Kinks
# The Stooges
# Frank Sinatra
# Justin Bieber
# Kendrick Lamar
# Wu-Tang Clan
# 2Pac
# David Bowie
# PJ Harvey
# Phil Collins
# Bruce Springsteen
# Ed Sheeran
# Bob Marley & The Wailers
# Santana
# Massive Attack
# Iron Maiden
# Tom Waits
# ABBA
# Frank Ocean
# Guns N’ Roses
# Kanye West
# Modest Mouse
# Ramones
# Portishead
# Red Hot Chili Peppers
# Little Richard
# Sonic Youth
# Elton John
# Creedence Clearwater Revival
# Beyoncé
# Steely Dan
# Elvis Costello
# The Four Tops
# Justin Timberlake
# Britney Spears
# Donna Summer
# Bob Dylan
# Wilco
# Ween
# Alice in Chains
# Bon Jovi
# The Smiths
# AC/DC
# Nicki Minaj
# The Beach Boys
# Elliott Smith
# Beck
# Nine Inch Nails
# Sufjan Stevens
# Public Enemy
# Talking Heads
# New Order
# Michael Jackson
# Janis Joplin
# Drake
# Prince
# R.E.M.

# %%
pd.DataFrame(songs, columns=['Id', 'Title', 'Artist', 'Page Views', 'Pyongs Count', 'Annotation Count']).to_csv('songs.csv')

# %%
import lyricsgenius as lg
import pandas as pd
TOKEN = open("token.txt", "r").read()
genius = lg.Genius(TOKEN, skip_non_songs=True, 
                   excluded_terms=["(Remix)", "(Live)", "- Live", "- Remix"], remove_section_headers=True)

# %%
df = pd.read_csv('songs_with_lyrics.csv').drop('Unnamed: 0', axis=1)
# start = 12571
# for i, row in list(df.iterrows())[start:]:
for i in list(df.loc[df['Lyrics'] == "''"].index):
    row = df.iloc[i]
    for j in range(5):
        try:
            lyrics = genius.lyrics(song_id=row['Id'])
            break
        except requests.Timeout:
            print("Timeout")
            # df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
# Timeout
# 12871 Warning Sign Talking Heads
# 12872 Radio Head Talking Heads
# 12873 Paper Talking Heads
# 12874 Stay Hungry Talking Heads
# 12875 First Week/Last Week... Carefree Talking Heads
# 12876 With Our Love Talking Heads
# 12877 Electric Guitar Talking Heads
# 12878 Who Is It? Talking Heads
# 12879 Blue Monday New Order
# 12880 Bizarre Love Triangle New Order
# 12881 Age of Consent New Order
# 12882 True Faith New Order
# 12883 Ceremony New Order
# 12884 World In Motion New Order
# 12885 Temptation New Order
# 12886 Leave Me Alone New Order
# 12887 Regret New Order
# 12888 Love Vigilantes New Order
# 12889 Your Silent Face New Order
# 12890 The Perfect Kiss New Order
# 12891 Dreams Never End New Order
# 12892 Restless New Order
# 12893 Crystal New Order
# 12894 Tutti Frutti New Order
# 12895 Singularity New Order
# 12896 The Village New Order
# 12897 Sub-Culture New Order
# 12898 Thieves Like Us New Order
# Timeout
# 12899 5 8 6 New Order
# 12900 1963 New Order
# 12901 We All Stand New Order
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/New-order-elegia-lyrics
# 12902 Elegia New Order
# 12903 Ultraviolence New Order
# 12904 Procession New Order
# 12905 Fine Time New Order
# 12906 Plastic New Order
# 12907 Vanishing Point New Order
# 12908 Ecstasy New Order
# 12909 Round and Round New Order
# 12910 Stray Dog New Order
# 12911 Confusion New Order
# 12912 Everything’s Gone Green New Order
# 12913 Superheated New Order
# 12914 In a Lonely Place New Order
# 12915 All The Way New Order
# 12916 Billie Jean Michael Jackson
# 12917 Smooth Criminal Michael Jackson
# 12918 They Don’t Care About Us Michael Jackson
# 12919 Wanna Be Startin’ Somethin’ Michael Jackson
# 12920 Thriller Michael Jackson
# 12921 Man in the Mirror Michael Jackson
# 12922 Human Nature Michael Jackson
# 12923 Beat It Michael Jackson
# 12924 Dirty Diana Michael Jackson
# 12925 Bad Michael Jackson
# 12926 Black or White Michael Jackson
# 12927 Heal the World Michael Jackson
# 12928 Don’t Stop ’Til You Get Enough Michael Jackson
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-137-b06eaa3e9a8c> in <module>
#       4     for j in range(5):
#       5         try:
# ----> 6             lyrics = genius.lyrics(song_id=row['Id'])
#       7             break
#       8         except requests.Timeout:
#
# C:\ProgramData\Anaconda3\lib\site-packages\lyricsgenius\genius.py in lyrics(self, song_id, song_url, remove_section_headers)
#     126             path = song_url.replace("https://genius.com/", "")
#     127         else:
# --> 128             path = self.song(song_id)['song']['path'][1:]
#     129
#     130         # Scrape the song lyrics from the HTML
#
# C:\ProgramData\Anaconda3\lib\site-packages\lyricsgenius\api\api.py in song(self, song_id, text_format)
#     435         endpoint = "songs/{id}".format(id=song_id)
#     436         params = {'text_format': text_format or self.response_format}
# --> 437         return self._make_request(endpoint, params_=params)
#     438
#     439     def web_page(self, raw_annotatable_url=None, canonical_url=None, og_url=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\lyricsgenius\api\base.py in _make_request(self, path, method, params_, public_api, web, **kwargs)
#      73             tries += 1
#      74             try:
# ---> 75                 response = self._session.request(method, uri,
#      76                                                  timeout=self.timeout,
#      77                                                  params=params_,
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
df.to_csv('songs_with_lyrics.csv')

# %%
res = session.request('GET', 'https://api.genius.com/songs/2843755', headers=authorization_header).json()

# %%
res['response']['song']
# Out:
# {'annotation_count': 3,
#  'api_path': '/songs/2843755',
#  'apple_music_id': None,
#  'apple_music_player_url': 'https://genius.com/songs/2843755/apple_music_player',
#  'artist_names': 'Frank Ocean',
#  'description': {'dom': {'tag': 'root',
#    'children': [{'tag': 'p', 'children': ['?']}]}},
#  'embed_content': "<div id='rg_embed_link_2843755' class='rg_embed_link' data-song-id='2843755'>Read <a href='https://genius.com/Frank-ocean-godspeed-screenplay-episode-1-scene-1-annotated'>“Godspeed Screenplay (Episode 1, Scene 1)” by Frank\xa0Ocean</a> on Genius</div> <script crossorigin src='//genius.com/songs/2843755/embed.js'></script>",
#  'featured_video': False,
#  'full_title': 'Godspeed Screenplay (Episode 1, Scene 1) by\xa0Frank\xa0Ocean',
#  'header_image_thumbnail_url': 'https://images.genius.com/9491d0ed6473080fd7b62da1568da37b.300x300x1.jpg',
#  'header_image_url': 'https://images.genius.com/9491d0ed6473080fd7b62da1568da37b.700x700x1.jpg',
#  'id': 2843755,
#  'lyrics_owner_id': 104344,
#  'lyrics_placeholder_reason': None,
#  'lyrics_state': 'complete',
#  'path': '/Frank-ocean-godspeed-screenplay-episode-1-scene-1-annotated',
#  'pyongs_count': 1,
#  'recording_location': None,
#  'release_date': '2016-08-20',
#  'release_date_for_display': 'August 20, 2016',
#  'song_art_image_thumbnail_url': 'https://images.genius.com/9491d0ed6473080fd7b62da1568da37b.300x300x1.jpg',
#  'song_art_image_url': 'https://images.genius.com/9491d0ed6473080fd7b62da1568da37b.700x700x1.jpg',
#  'stats': {'accepted_annotations': 3,
#   'contributors': 6,
#   'iq_earners': 6,
#   'transcribers': 2,
#   'unreviewed_annotations': 0,
#   'verified_annotations': 0,
#   'hot': False,
#   'pageviews': 19349},
#  'title': 'Godspeed Screenplay (Episode 1, Scene 1)',
#  'title_with_featured': 'Godspeed Screenplay (Episode 1, Scene 1)',
#  'url': 'https://genius.com/Frank-ocean-godspeed-screenplay-episode-1-scene-1-annotated',
#  'current_user_metadata': {'permissions': ['see_pageviews',
#    'view_apple_music_player',
#    'create_comment',
#    'view_song_story_gallery'],
#   'excluded_permissions': ['follow',
#    'award_transcription_iq',
#    'remove_transcription_iq',
#    'pyong',
#    'edit_lyrics',
#    'view_annotation_engagement_data',
#    'publish',
#    'unpublish',
#    'edit_spotify_details',
#    'hide',
#    'unhide',
#    'toggle_featured_video',
#    'add_pinned_annotation_to',
#    'add_community_annotation_to',
#    'destroy',
#    'mark_as_not_spam',
#    'edit_spotify_annotations_for',
#    'verify_lyrics',
#    'unverify_lyrics',
#    'edit_anything',
#    'edit_any_media',
#    'edit',
#    'rename',
#    'edit_tags',
#    'watch_fact_track',
#    'reindex',
#    'view_lyrics_synchronization',
#    'enable_media',
#    'disable_media',
#    'edit_lyrics_or_annotation_brackets',
#    'see_editorial_indicators',
#    'view_attribution_visualization',
#    'edit_annotation_brackets',
#    'preview_lyrics_for_export',
#    'hide_apple_player',
#    'unhide_apple_player',
#    'trigger_apple_match',
#    'mark_lyrics_evaluation_as_approved',
#    'mark_lyrics_evaluation_as_staff_approved',
#    'mark_lyrics_evaluation_as_unapproved',
#    'mark_lyrics_evaluation_as_un_staff_approved',
#    'view_transcriber_media_player',
#    'override_apple_match',
#    'set_song_color_gradient',
#    'edit_youtube_url',
#    'edit_soundcloud_url',
#    'edit_spotify_uuid',
#    'edit_vevo_url',
#    'moderate_annotations',
#    'create_annotation',
#    'see_short_id',
#    'manage_chart_item',
#    'create_tag',
#    'propose_lyrics_edit',
#    'moderate_lyrics_edit_proposals',
#    'preview_react_song_page'],
#   'interactions': {'pyong': False, 'following': False},
#   'relationships': {},
#   'iq_by_action': {}},
#  'album': {'api_path': '/albums/164567',
#   'cover_art_url': 'https://images.genius.com/9491d0ed6473080fd7b62da1568da37b.700x700x1.jpg',
#   'full_title': "Boys Don't Cry (Magazine) by Frank Ocean",
#   'id': 164567,
#   'name': 'Boys Don’t Cry (Magazine)',
#   'url': 'https://genius.com/albums/Frank-ocean/Boys-don-t-cry-magazine',
#   'artist': {'api_path': '/artists/1985',
#    'header_image_url': 'https://images.genius.com/31a4b0b89a988ed7fff5beb83808ab56.1000x562x1.jpg',
#    'id': 1985,
#    'image_url': 'https://images.genius.com/78a9a1403027e5778b473c71204b1ac0.728x728x1.jpg',
#    'is_meme_verified': True,
#    'is_verified': True,
#    'name': 'Frank Ocean',
#    'url': 'https://genius.com/artists/Frank-ocean',
#    'iq': 7107}},
#  'custom_performances': [],
#  'description_annotation': {'_type': 'referent',
#   'annotator_id': 104344,
#   'annotator_login': 'streetlights',
#   'api_path': '/referents/10278002',
#   'classification': 'needs_exegesis',
#   'fragment': 'Godspeed Screenplay (Episode 1, Scene 1)',
#   'id': 10278002,
#   'is_description': True,
#   'path': '/10278002/Frank-ocean-godspeed-screenplay-episode-1-scene-1/Godspeed-screenplay-episode-1-scene-1',
#   'range': {'content': 'Godspeed Screenplay (Episode 1, Scene 1)'},
#   'song_id': 2843755,
#   'url': 'https://genius.com/10278002/Frank-ocean-godspeed-screenplay-episode-1-scene-1/Godspeed-screenplay-episode-1-scene-1',
#   'verified_annotator_ids': [],
#   'annotatable': {'api_path': '/songs/2843755',
#    'client_timestamps': {'updated_by_human_at': 1544817584,
#     'lyrics_updated_at': 1544817584},
#    'context': 'Frank Ocean',
#    'id': 2843755,
#    'image_url': 'https://images.genius.com/9491d0ed6473080fd7b62da1568da37b.700x700x1.jpg',
#    'link_title': 'Godspeed Screenplay (Episode 1, Scene 1) by\xa0Frank\xa0Ocean',
#    'title': 'Godspeed Screenplay (Episode 1, Scene 1)',
#    'type': 'Song',
#    'url': 'https://genius.com/Frank-ocean-godspeed-screenplay-episode-1-scene-1-annotated'},
#   'annotations': [{'api_path': '/annotations/10278002',
#     'body': {'dom': {'tag': 'root'}},
#     'comment_count': 0,
#     'community': True,
#     'custom_preview': None,
#     'has_voters': False,
#     'id': 10278002,
#     'pinned': False,
#     'share_url': 'https://genius.com/10278002',
#     'source': None,
#     'state': 'needs_exegesis',
#     'url': 'https://genius.com/10278002/Frank-ocean-godspeed-screenplay-episode-1-scene-1/Godspeed-screenplay-episode-1-scene-1',
#     'verified': False,
#     'votes_total': 0,
#     'current_user_metadata': {'permissions': [],
#      'excluded_permissions': ['vote',
#       'edit',
#       'cosign',
#       'uncosign',
#       'destroy',
#       'accept',
#       'reject',
#       'see_unreviewed',
#       'clear_votes',
#       'propose_edit_to',
#       'pin_to_profile',
#       'unpin_from_profile',
#       'update_source',
#       'edit_custom_preview',
#       'create_comment'],
#      'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#      'iq_by_action': {}},
#     'authors': [{'attribution': 1.0,
#       'pinned_role': None,
#       'user': {'api_path': '/users/104344',
#        'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/ce79081085ed59d85a103afd4b07bc74',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.genius.com/avatars/thumb/ce79081085ed59d85a103afd4b07bc74',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.genius.com/avatars/small/ce79081085ed59d85a103afd4b07bc74',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.genius.com/avatars/medium/ce79081085ed59d85a103afd4b07bc74',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://images.genius.com/ec0ca5aa13e436e4993cffdff81fafcf.800x800x1.jpg',
#        'human_readable_role_for_display': 'Staff',
#        'id': 104344,
#        'iq': 2883660,
#        'login': 'streetlights',
#        'name': '\u200bstreetlights',
#        'role_for_display': 'staff',
#        'url': 'https://genius.com/streetlights',
#        'current_user_metadata': {'permissions': [],
#         'excluded_permissions': ['follow'],
#         'interactions': {'following': False}}}}],
#     'cosigned_by': [],
#     'rejection_comment': None,
#     'verified_by': None}]},
#  'featured_artists': [],
#  'lyrics_marked_complete_by': None,
#  'media': [],
#  'primary_artist': {'api_path': '/artists/1985',
#   'header_image_url': 'https://images.genius.com/31a4b0b89a988ed7fff5beb83808ab56.1000x562x1.jpg',
#   'id': 1985,
#   'image_url': 'https://images.genius.com/78a9a1403027e5778b473c71204b1ac0.728x728x1.jpg',
#   'is_meme_verified': True,
#   'is_verified': True,
#   'name': 'Frank Ocean',
#   'url': 'https://genius.com/artists/Frank-ocean',
#   'iq': 7107},
#  'producer_artists': [],
#  'song_relationships': [{'relationship_type': 'samples',
#    'type': 'samples',
#    'songs': []},
#   {'relationship_type': 'sampled_in', 'type': 'sampled_in', 'songs': []},
#   {'relationship_type': 'interpolates', 'type': 'interpolates', 'songs': []},
#   {'relationship_type': 'interpolated_by',
#    'type': 'interpolated_by',
#    'songs': []},
#   {'relationship_type': 'cover_of', 'type': 'cover_of', 'songs': []},
#   {'relationship_type': 'covered_by', 'type': 'covered_by', 'songs': []},
#   {'relationship_type': 'remix_of', 'type': 'remix_of', 'songs': []},
#   {'relationship_type': 'remixed_by', 'type': 'remixed_by', 'songs': []},
#   {'relationship_type': 'live_version_of',
#    'type': 'live_version_of',
#    'songs': []},
#   {'relationship_type': 'performed_live_as',
#    'type': 'performed_live_as',
#    'songs': []}],
#  'verified_annotations_by': [],
#  'verified_contributors': [{'contributions': ['answers'],
#    'artist': {'api_path': '/artists/1985',
#     'header_image_url': 'https://images.genius.com/31a4b0b89a988ed7fff5beb83808ab56.1000x562x1.jpg',
#     'id': 1985,
#     'image_url': 'https://images.genius.com/78a9a1403027e5778b473c71204b1ac0.728x728x1.jpg',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Frank Ocean',
#     'url': 'https://genius.com/artists/Frank-ocean',
#     'iq': 7107},
#    'user': {'api_path': '/users/4328460',
#     'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/72223e2eb85c2497ea5fb029d3897197',
#       'bounding_box': {'width': 16, 'height': 16}},
#      'thumb': {'url': 'https://images.genius.com/avatars/thumb/72223e2eb85c2497ea5fb029d3897197',
#       'bounding_box': {'width': 32, 'height': 32}},
#      'small': {'url': 'https://images.genius.com/avatars/small/72223e2eb85c2497ea5fb029d3897197',
#       'bounding_box': {'width': 100, 'height': 100}},
#      'medium': {'url': 'https://images.genius.com/avatars/medium/72223e2eb85c2497ea5fb029d3897197',
#       'bounding_box': {'width': 300, 'height': 400}}},
#     'header_image_url': 'https://images.genius.com/31a4b0b89a988ed7fff5beb83808ab56.1000x562x1.jpg',
#     'human_readable_role_for_display': 'Verified Artist',
#     'id': 4328460,
#     'iq': 7107,
#     'login': 'frankocean',
#     'name': 'Frank Ocean',
#     'role_for_display': 'verified_artist',
#     'url': 'https://genius.com/frankocean',
#     'current_user_metadata': {'permissions': [],
#      'excluded_permissions': ['follow'],
#      'interactions': {'following': False}}}}],
#  'verified_lyrics_by': [],
#  'writer_artists': []}

# %%
session.request('GET', 'https://api.genius.com/search/', params={'q': "1999 prince"}, headers=authorization_header).json()
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 18,
#      'api_path': '/songs/2770',
#      'artist_names': 'Prince',
#      'full_title': '1999 by\xa0Prince',
#      'header_image_thumbnail_url': 'https://images.genius.com/f9d763e693ae440f5cc5a95ba74a6809.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/f9d763e693ae440f5cc5a95ba74a6809.1000x1000x1.jpg',
#      'id': 2770,
#      'lyrics_owner_id': 7,
#      'lyrics_state': 'complete',
#      'path': '/Prince-1999-lyrics',
#      'pyongs_count': 14,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/05106ba984ad1810e9043d575d8d5d95.300x292x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/05106ba984ad1810e9043d575d8d5d95.600x583x1.jpg',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 240733},
#      'title': '1999',
#      'title_with_featured': '1999',
#      'url': 'https://genius.com/Prince-1999-lyrics',
#      'primary_artist': {'api_path': '/artists/660',
#       'header_image_url': 'https://images.genius.com/e7e3b4db311646f47ba8337052b1a760.1000x500x1.jpg',
#       'id': 660,
#       'image_url': 'https://images.genius.com/6f05e738193e0c5bb8ff3adb6eb8766a.470x470x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Prince',
#       'url': 'https://genius.com/artists/Prince'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/1337919',
#      'artist_names': 'Prince and the Revolution (Ft. Rosario Dawson)',
#      'full_title': 'Rosario (1999) by\xa0Prince\xa0and the Revolution (Ft.\xa0Rosario\xa0Dawson)',
#      'header_image_thumbnail_url': 'https://images.genius.com/d010c7dcbb4808fd3e5120b9cc76e366.300x298x1.jpg',
#      'header_image_url': 'https://images.genius.com/d010c7dcbb4808fd3e5120b9cc76e366.384x381x1.jpg',
#      'id': 1337919,
#      'lyrics_owner_id': 913317,
#      'lyrics_state': 'complete',
#      'path': '/Prince-and-the-revolution-rosario-1999-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/d010c7dcbb4808fd3e5120b9cc76e366.300x298x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/d010c7dcbb4808fd3e5120b9cc76e366.384x381x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False},
#      'title': 'Rosario (1999)',
#      'title_with_featured': 'Rosario (1999) (Ft.\xa0Rosario\xa0Dawson)',
#      'url': 'https://genius.com/Prince-and-the-revolution-rosario-1999-lyrics',
#      'primary_artist': {'api_path': '/artists/43316',
#       'header_image_url': 'https://images.genius.com/cb25daa2fcdb2a98b3dca6fb39f535a9.1000x523x1.jpg',
#       'id': 43316,
#       'image_url': 'https://images.genius.com/d47be45ca02352f2603dfc138b15af2a.973x973x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Prince and the Revolution',
#       'url': 'https://genius.com/artists/Prince-and-the-revolution'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/5609371',
#      'artist_names': 'Limp Bizkit',
#      'full_title': '1999 (Prince Cover) [Live] by\xa0Limp\xa0Bizkit',
#      'header_image_thumbnail_url': 'https://images.genius.com/d940ad8c6d9405aaca9423ccfa5acf73.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/d940ad8c6d9405aaca9423ccfa5acf73.408x408x1.jpg',
#      'id': 5609371,
#      'lyrics_owner_id': 10962780,
#      'lyrics_state': 'complete',
#      'path': '/Limp-bizkit-1999-prince-cover-live-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/d940ad8c6d9405aaca9423ccfa5acf73.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/d940ad8c6d9405aaca9423ccfa5acf73.408x408x1.jpg',
#      'stats': {'unreviewed_annotations': 1, 'hot': False},
#      'title': '1999 (Prince Cover) [Live]',
#      'title_with_featured': '1999 (Prince Cover) [Live]',
#      'url': 'https://genius.com/Limp-bizkit-1999-prince-cover-live-lyrics',
#      'primary_artist': {'api_path': '/artists/8346',
#       'header_image_url': 'https://images.genius.com/e98faffbcb0bdc9677260d9b81819ea6.1000x1000x1.jpg',
#       'id': 8346,
#       'image_url': 'https://images.genius.com/d940ad8c6d9405aaca9423ccfa5acf73.408x408x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Limp Bizkit',
#       'url': 'https://genius.com/artists/Limp-bizkit'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 418,
#      'api_path': '/songs/409534',
#      'artist_names': 'Radio Hamburg',
#      'full_title': 'Radio Hamburg TOP 825 by\xa0Radio\xa0Hamburg',
#      'header_image_thumbnail_url': 'https://images.genius.com/f49913f3e174f82a90c64028ec7be8f4.300x291x1.gif',
#      'header_image_url': 'https://images.genius.com/f49913f3e174f82a90c64028ec7be8f4.1000x969x1.gif',
#      'id': 409534,
#      'lyrics_owner_id': 215579,
#      'lyrics_state': 'complete',
#      'path': '/Radio-hamburg-radio-hamburg-top-825-lyrics',
#      'pyongs_count': 4,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/f49913f3e174f82a90c64028ec7be8f4.300x291x1.gif',
#      'song_art_image_url': 'https://images.genius.com/f49913f3e174f82a90c64028ec7be8f4.1000x969x1.gif',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 27941},
#      'title': 'Radio Hamburg TOP 825',
#      'title_with_featured': 'Radio Hamburg TOP 825',
#      'url': 'https://genius.com/Radio-hamburg-radio-hamburg-top-825-lyrics',
#      'primary_artist': {'api_path': '/artists/169143',
#       'header_image_url': 'https://images.genius.com/f49913f3e174f82a90c64028ec7be8f4.1000x969x1.gif',
#       'id': 169143,
#       'image_url': 'https://images.genius.com/f49913f3e174f82a90c64028ec7be8f4.1000x969x1.gif',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radio Hamburg',
#       'url': 'https://genius.com/artists/Radio-hamburg'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/2215763',
#      'artist_names': 'Back beach all stars',
#      'full_title': 'Living On A Prayer by\xa0Back\xa0beach all stars',
#      'header_image_thumbnail_url': 'https://assets.genius.com/images/default_cover_image.png?1638401045',
#      'header_image_url': 'https://assets.genius.com/images/default_cover_image.png?1638401045',
#      'id': 2215763,
#      'lyrics_owner_id': 1549345,
#      'lyrics_state': 'complete',
#      'path': '/Back-beach-all-stars-living-on-a-prayer-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://assets.genius.com/images/default_cover_image.png?1638401045',
#      'song_art_image_url': 'https://assets.genius.com/images/default_cover_image.png?1638401045',
#      'stats': {'unreviewed_annotations': 1, 'hot': False},
#      'title': 'Living On A Prayer',
#      'title_with_featured': 'Living On A Prayer',
#      'url': 'https://genius.com/Back-beach-all-stars-living-on-a-prayer-lyrics',
#      'primary_artist': {'api_path': '/artists/484011',
#       'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1638401045',
#       'id': 484011,
#       'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1638401045',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Back beach all stars',
#       'url': 'https://genius.com/artists/Back-beach-all-stars'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/2216721',
#      'artist_names': 'Jan Delay',
#      'full_title': 'Pump up Medley - Live by\xa0Jan\xa0Delay',
#      'header_image_thumbnail_url': 'https://images.genius.com/a231fc8316659240dd3fa96db2dcaeb4.300x438x1.jpg',
#      'header_image_url': 'https://images.genius.com/a231fc8316659240dd3fa96db2dcaeb4.446x651x1.jpg',
#      'id': 2216721,
#      'lyrics_owner_id': 1549345,
#      'lyrics_state': 'complete',
#      'path': '/Jan-delay-pump-up-medley-live-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/a231fc8316659240dd3fa96db2dcaeb4.300x438x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/a231fc8316659240dd3fa96db2dcaeb4.446x651x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False},
#      'title': 'Pump up Medley - Live',
#      'title_with_featured': 'Pump up Medley - Live',
#      'url': 'https://genius.com/Jan-delay-pump-up-medley-live-lyrics',
#      'primary_artist': {'api_path': '/artists/12512',
#       'header_image_url': 'https://images.genius.com/a231fc8316659240dd3fa96db2dcaeb4.446x651x1.jpg',
#       'id': 12512,
#       'image_url': 'https://images.genius.com/a231fc8316659240dd3fa96db2dcaeb4.446x651x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Jan Delay',
#       'url': 'https://genius.com/artists/Jan-delay'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 15,
#      'api_path': '/songs/3738075',
#      'artist_names': 'TAKEAPICTUREWITME!',
#      'full_title': 'My album ratings 2 by\xa0TAKEAPICTUREWITME!',
#      'header_image_thumbnail_url': 'https://images.genius.com/f77fb29848692f635eac419e9aa01978.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/f77fb29848692f635eac419e9aa01978.656x656x1.jpg',
#      'id': 3738075,
#      'lyrics_owner_id': 5335884,
#      'lyrics_state': 'complete',
#      'path': '/Takeapicturewitme-my-album-ratings-2-annotated',
#      'pyongs_count': 1,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/f77fb29848692f635eac419e9aa01978.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/f77fb29848692f635eac419e9aa01978.656x656x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False},
#      'title': 'My album ratings 2',
#      'title_with_featured': 'My album ratings 2',
#      'url': 'https://genius.com/Takeapicturewitme-my-album-ratings-2-annotated',
#      'primary_artist': {'api_path': '/artists/1322680',
#       'header_image_url': 'https://images.genius.com/827fb4de7a9eb85cd369b3775d7cac76.562x1000x1.png',
#       'id': 1322680,
#       'image_url': 'https://images.genius.com/f77fb29848692f635eac419e9aa01978.656x656x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'TAKEAPICTUREWITME!',
#       'url': 'https://genius.com/artists/Takeapicturewitme',
#       'iq': 16379}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 3,
#      'api_path': '/songs/4389744',
#      'artist_names': 'SamuelJarred',
#      'full_title': "SamuelJarred's Vinyl & CD Collection by\xa0SamuelJarred",
#      'header_image_thumbnail_url': 'https://images.genius.com/7ccdaa5c26676cadf06f2f6281cbf764.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/7ccdaa5c26676cadf06f2f6281cbf764.539x539x1.jpg',
#      'id': 4389744,
#      'lyrics_owner_id': 3225368,
#      'lyrics_state': 'complete',
#      'path': '/Samueljarred-samueljarreds-vinyl-and-cd-collection-annotated',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/7ccdaa5c26676cadf06f2f6281cbf764.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/7ccdaa5c26676cadf06f2f6281cbf764.539x539x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False},
#      'title': 'SamuelJarred’s Vinyl & CD Collection',
#      'title_with_featured': "SamuelJarred's Vinyl & CD Collection",
#      'url': 'https://genius.com/Samueljarred-samueljarreds-vinyl-and-cd-collection-annotated',
#      'primary_artist': {'api_path': '/artists/1112147',
#       'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1638401045',
#       'id': 1112147,
#       'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1638401045',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'SamuelJarred',
#       'url': 'https://genius.com/artists/Samueljarred'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/5850383',
#      'artist_names': 'Taomi',
#      'full_title': '1998 by\xa0Taomi',
#      'header_image_thumbnail_url': 'https://images.genius.com/7f7537e58026c257b40c8ec5b2333861.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/7f7537e58026c257b40c8ec5b2333861.900x900x1.jpg',
#      'id': 5850383,
#      'lyrics_owner_id': 9044083,
#      'lyrics_state': 'complete',
#      'path': '/Taomi-1998-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/7f7537e58026c257b40c8ec5b2333861.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/7f7537e58026c257b40c8ec5b2333861.900x900x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False},
#      'title': '1998',
#      'title_with_featured': '1998',
#      'url': 'https://genius.com/Taomi-1998-lyrics',
#      'primary_artist': {'api_path': '/artists/1694924',
#       'header_image_url': 'https://images.genius.com/83b16ad71da5d43622d75e0cfbea126d.1000x1000x1.jpg',
#       'id': 1694924,
#       'image_url': 'https://images.genius.com/83b16ad71da5d43622d75e0cfbea126d.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taomi',
#       'url': 'https://genius.com/artists/Taomi'}}}]}}

# %%
print(getArtistId('David Bowie'))
uri = 'https://api.genius.com/artists/{}/songs'.format(getArtistId('David Bowie'))
params = {'sort': 'popularity', 'per_page': 50, 'page': 1}
response = session.request('GET', uri, params=params, headers=authorization_header)
print([song for song in response.json()['response']['songs'] if song['primary_artist']['name'] == "David Bowie"][0])
# Out:
# -1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-175-67676524a97f> in <module>
#       3 params = {'sort': 'popularity', 'per_page': 50, 'page': 1}
#       4 response = session.request('GET', uri, params=params, headers=authorization_header)
# ----> 5 print([song for song in response.json()['response']['songs'] if song['primary_artist']['name'] == "David Bowie"][0])
#
# KeyError: 'response'

# %%
print([song for song in response.json()['response']['songs'] if song['primary_artist']['name'] == "Aphex Twin"][0])
# Out:
# {'annotation_count': 2, 'api_path': '/songs/128396', 'artist_names': 'Aphex Twin', 'full_title': 'Avril 14th by\xa0Aphex\xa0Twin', 'header_image_thumbnail_url': 'https://images.genius.com/768f27a906ebe53e4f98398167fb84f0.300x300x1.png', 'header_image_url': 'https://images.genius.com/768f27a906ebe53e4f98398167fb84f0.1000x1000x1.png', 'id': 128396, 'lyrics_owner_id': 116340, 'lyrics_state': 'complete', 'path': '/Aphex-twin-avril-14th-lyrics', 'pyongs_count': 4, 'song_art_image_thumbnail_url': 'https://images.genius.com/768f27a906ebe53e4f98398167fb84f0.300x300x1.png', 'song_art_image_url': 'https://images.genius.com/768f27a906ebe53e4f98398167fb84f0.1000x1000x1.png', 'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 15070}, 'title': 'Avril 14th', 'title_with_featured': 'Avril 14th', 'url': 'https://genius.com/Aphex-twin-avril-14th-lyrics', 'primary_artist': {'api_path': '/artists/38515', 'header_image_url': 'https://images.genius.com/b2d3bde9ef1f7f9b72f3b74f4ebb069f.1000x429x1.jpg', 'id': 38515, 'image_url': 'https://images.genius.com/1182d28a52dc0239f43aab4ac617f9f1.570x570x1.jpg', 'is_meme_verified': False, 'is_verified': False, 'name': 'Aphex Twin', 'url': 'https://genius.com/artists/Aphex-twin'}}

# %%
len(current_df.Artist.unique())
# Out:
# 113

# %%
current_df.drop_duplicates(['Title', 'Artist']).to_csv('songs2.csv')

# %%
df.loc[:, ~df.columns.str.contains('^Unnamed')].to_csv('songs_with_lyrics.csv')

# %%
df = pd.read_csv('songs_with_lyrics.csv')
df.drop('Unnamed: 0', axis=1).columns
# Out:
# Index(['Id', 'Title', 'Artist', 'Page Views', 'Pyongs Count',
#        'Annotation Count', 'Lyrics'],
#       dtype='object')

# %%
df = pd.read_csv('songs_with_lyrics.csv')
df['Lyrics'] = df['Lyrics'].fillna('').map(repr)
df.to_csv('songs_with_lyrics.csv')

# %%
from ast import literal_eval
df['Lyrics'].map(literal_eval)
# Out:
# 0        When you were here before\nCouldn't look you i...
# 1        Karma police, arrest this man\nHe talks in mat...
# 2        A heart that's full up like a landfill\nA job ...
# 3        Please, could you stop the noise?\nI'm trying ...
# 4        Wake from your sleep\nThe drying of your tears...
#                                ...
# 13752
# 13753
# 13754
# 13755
# 13756
# Name: Lyrics, Length: 13757, dtype: object

# %%
df = pd.read_csv('songs_with_lyrics.csv').drop('Unnamed: 0', axis=1)

# %%
list(df.loc[df['Lyrics'] == "''"].index)
# Out:
# [91,
#  106,
#  110,
#  137,
#  144,
#  603,
#  765,
#  794,
#  799,
#  800,
#  920,
#  931,
#  936,
#  940,
#  948,
#  954,
#  1640,
#  1690,
#  1854,
#  1857,
#  2220,
#  2263,
#  2267,
#  2268,
#  2271,
#  2552,
#  2561,
#  2732,
#  2734,
#  2736,
#  2740,
#  2745,
#  2758,
#  3233,
#  3248,
#  3299,
#  3323,
#  3329,
#  3554,
#  3563,
#  3564,
#  3578,
#  3835,
#  3854,
#  3927,
#  4064,
#  4070,
#  4075,
#  4076,
#  4078,
#  4082,
#  4083,
#  4084,
#  4086,
#  4088,
#  4089,
#  4090,
#  4138,
#  4140,
#  4157,
#  4169,
#  4269,
#  4274,
#  4314,
#  4424,
#  5264,
#  5407,
#  5411,
#  5522,
#  5551,
#  5587,
#  5588,
#  5602,
#  5623,
#  5624,
#  5625,
#  5628,
#  5629,
#  5632,
#  5664,
#  5923,
#  6041,
#  6064,
#  6071,
#  6085,
#  6174,
#  6209,
#  6240,
#  6313,
#  6314,
#  6316,
#  6388,
#  6438,
#  6443,
#  6451,
#  6464,
#  6465,
#  6466,
#  6568,
#  6579,
#  6592,
#  6610,
#  7652,
#  7655,
#  7657,
#  8170,
#  8247,
#  8327,
#  8911,
#  8920,
#  8950,
#  8953,
#  9011,
#  9017,
#  9520,
#  9639,
#  9646,
#  9664,
#  9680,
#  9945,
#  9949,
#  9952,
#  9963,
#  9978,
#  9982,
#  9999,
#  10012,
#  10068,
#  10330,
#  10418,
#  10422,
#  10430,
#  10525,
#  10534,
#  10831,
#  11898,
#  12033,
#  12037,
#  12349,
#  12450,
#  12451,
#  12452,
#  12453,
#  12454,
#  12455,
#  12456,
#  12457,
#  12458,
#  12459,
#  12460,
#  12461,
#  12462,
#  12463,
#  12464,
#  12465,
#  12466,
#  12467,
#  12468,
#  12469,
#  12470,
#  12471,
#  12472,
#  12473,
#  12474,
#  12475,
#  12476,
#  12477,
#  12478,
#  12479,
#  12480,
#  12481,
#  12482,
#  12483,
#  12484,
#  12485,
#  12486,
#  12487,
#  12488,
#  12489,
#  12490,
#  12491,
#  12492,
#  12493,
#  12494,
#  12495,
#  12496,
#  12497,
#  12498,
#  12499,
#  12500,
#  12501,
#  12502,
#  12503,
#  12504,
#  12505,
#  12506,
#  12507,
#  12508,
#  12509,
#  12510,
#  12511,
#  12512,
#  12513,
#  12514,
#  12515,
#  12516,
#  12517,
#  12518,
#  12519,
#  12520,
#  12521,
#  12522,
#  12523,
#  12524,
#  12525,
#  12526,
#  12527,
#  12528,
#  12529,
#  12530,
#  12531,
#  12532,
#  12533,
#  12534,
#  12535,
#  12536,
#  12537,
#  12538,
#  12539,
#  12540,
#  12541,
#  12542,
#  12543,
#  12544,
#  12545,
#  12546,
#  12547,
#  12548,
#  12549,
#  12550,
#  12551,
#  12552,
#  12553,
#  12554,
#  12555,
#  12556,
#  12557,
#  12558,
#  12559,
#  12560,
#  12561,
#  12562,
#  12563,
#  12564,
#  12565,
#  12566,
#  12567,
#  12568,
#  12569,
#  12570,
#  12597,
#  12630,
#  12648,
#  12650,
#  12654,
#  12696,
#  12718,
#  12722,
#  12729,
#  12753,
#  12759,
#  12760,
#  12761,
#  12763,
#  12902,
#  12929,
#  12930,
#  12931,
#  12932,
#  12933,
#  12934,
#  12935,
#  12936,
#  12937,
#  12938,
#  12939,
#  12940,
#  12941,
#  12942,
#  12943,
#  12944,
#  12945,
#  12946,
#  12947,
#  12948,
#  12949,
#  12950,
#  12951,
#  12952,
#  12953,
#  12954,
#  12955,
#  12956,
#  12957,
#  12958,
#  12959,
#  12960,
#  12961,
#  12962,
#  12963,
#  12964,
#  12965,
#  12966,
#  12967,
#  12968,
#  12969,
#  12970,
#  12971,
#  12972,
#  12973,
#  12974,
#  12975,
#  12976,
#  12977,
#  12978,
#  12979,
#  12980,
#  12981,
#  12982,
#  12983,
#  12984,
#  12985,
#  12986,
#  12987,
#  12988,
#  12989,
#  12990,
#  12991,
#  12992,
#  12993,
#  12994,
#  12995,
#  12996,
#  12997,
#  12998,
#  12999,
#  13000,
#  13001,
#  13002,
#  13003,
#  13004,
#  13005,
#  13006,
#  13007,
#  13008,
#  13009,
#  13010,
#  13011,
#  13012,
#  13013,
#  13014,
#  13015,
#  13016,
#  13017,
#  13018,
#  13019,
#  13020,
#  13021,
#  13022,
#  13023,
#  13024,
#  13025,
#  13026,
#  13027,
#  13028,
#  13029,
#  13030,
#  13031,
#  13032,
#  13033,
#  13034,
#  13035,
#  13036,
#  13037,
#  13038,
#  13039,
#  13040,
#  13041,
#  13042,
#  13043,
#  13044,
#  13045,
#  13046,
#  13047,
#  13048,
#  13049,
#  13050,
#  13051,
#  13052,
#  13053,
#  13054,
#  13055,
#  13056,
#  13057,
#  13058,
#  13059,
#  13060,
#  13061,
#  13062,
#  13063,
#  13064,
#  13065,
#  13066,
#  13067,
#  13068,
#  13069,
#  13070,
#  13071,
#  13072,
#  13073,
#  13074,
#  13075,
#  13076,
#  13077,
#  13078,
#  13079,
#  13080,
#  13081,
#  13082,
#  13083,
#  13084,
#  13085,
#  13086,
#  13087,
#  13088,
#  13089,
#  13090,
#  13091,
#  13092,
#  13093,
#  13094,
#  13095,
#  13096,
#  13097,
#  13098,
#  13099,
#  13100,
#  13101,
#  13102,
#  13103,
#  13104,
#  13105,
#  13106,
#  13107,
#  13108,
#  13109,
#  13110,
#  13111,
#  13112,
#  13113,
#  13114,
#  13115,
#  13116,
#  13117,
#  13118,
#  13119,
#  13120,
#  13121,
#  13122,
#  13123,
#  13124,
#  13125,
#  13126,
#  13127,
#  13128,
#  13129,
#  13130,
#  13131,
#  13132,
#  13133,
#  13134,
#  13135,
#  13136,
#  13137,
#  13138,
#  13139,
#  13140,
#  13141,
#  13142,
#  13143,
#  13144,
#  13145,
#  13146,
#  13147,
#  13148,
#  13149,
#  13150,
#  13151,
#  13152,
#  13153,
#  13154,
#  13155,
#  13156,
#  13157,
#  13158,
#  13159,
#  13160,
#  13161,
#  13162,
#  13163,
#  13164,
#  13165,
#  13166,
#  13167,
#  13168,
#  13169,
#  13170,
#  13171,
#  13172,
#  13173,
#  13174,
#  13175,
#  13176,
#  13177,
#  13178,
#  13179,
#  13180,
#  13181,
#  13182,
#  13183,
#  13184,
#  13185,
#  13186,
#  13187,
#  13188,
#  13189,
#  13190,
#  13191,
#  13192,
#  13193,
#  13194,
#  13195,
#  13196,
#  13197,
#  13198,
#  13199,
#  13200,
#  13201,
#  13202,
#  13203,
#  13204,
#  13205,
#  13206,
#  13207,
#  13208,
#  13209,
#  13210,
#  13211,
#  13212,
#  13213,
#  13214,
#  13215,
#  13216,
#  13217,
#  13218,
#  13219,
#  13220,
#  13221,
#  13222,
#  13223,
#  13224,
#  13225,
#  13226,
#  13227,
#  13228,
#  13229,
#  13230,
#  13231,
#  13232,
#  13233,
#  13234,
#  13235,
#  13236,
#  13237,
#  13238,
#  13239,
#  13240,
#  13241,
#  13242,
#  13243,
#  13244,
#  13245,
#  13246,
#  13247,
#  13248,
#  13249,
#  13250,
#  13251,
#  13252,
#  13253,
#  13254,
#  13255,
#  13256,
#  13257,
#  13258,
#  13259,
#  13260,
#  13261,
#  13262,
#  13263,
#  13264,
#  13265,
#  13266,
#  13267,
#  13268,
#  13269,
#  13270,
#  13271,
#  13272,
#  13273,
#  13274,
#  13275,
#  13276,
#  13277,
#  13278,
#  13279,
#  13280,
#  13281,
#  13282,
#  13283,
#  13284,
#  13285,
#  13286,
#  13287,
#  13288,
#  13289,
#  13290,
#  13291,
#  13292,
#  13293,
#  13294,
#  13295,
#  13296,
#  13297,
#  13298,
#  13299,
#  13300,
#  13301,
#  13302,
#  13303,
#  13304,
#  13305,
#  13306,
#  13307,
#  13308,
#  13309,
#  13310,
#  13311,
#  13312,
#  13313,
#  13314,
#  13315,
#  13316,
#  13317,
#  13318,
#  13319,
#  13320,
#  13321,
#  13322,
#  13323,
#  13324,
#  13325,
#  13326,
#  13327,
#  13328,
#  13329,
#  13330,
#  13331,
#  13332,
#  13333,
#  13334,
#  13335,
#  13336,
#  13337,
#  13338,
#  13339,
#  13340,
#  13341,
#  13342,
#  13343,
#  13344,
#  13345,
#  13346,
#  13347,
#  13348,
#  13349,
#  13350,
#  13351,
#  13352,
#  13353,
#  13354,
#  13355,
#  13356,
#  13357,
#  13358,
#  13359,
#  13360,
#  13361,
#  13362,
#  13363,
#  13364,
#  13365,
#  13366,
#  13367,
#  13368,
#  13369,
#  13370,
#  13371,
#  13372,
#  13373,
#  13374,
#  13375,
#  13376,
#  13377,
#  13378,
#  13379,
#  13380,
#  13381,
#  13382,
#  13383,
#  13384,
#  13385,
#  13386,
#  13387,
#  13388,
#  13389,
#  13390,
#  13391,
#  13392,
#  13393,
#  13394,
#  13395,
#  13396,
#  13397,
#  13398,
#  13399,
#  13400,
#  13401,
#  13402,
#  13403,
#  13404,
#  13405,
#  13406,
#  13407,
#  13408,
#  13409,
#  13410,
#  13411,
#  13412,
#  13413,
#  13414,
#  13415,
#  13416,
#  13417,
#  13418,
#  13419,
#  13420,
#  13421,
#  13422,
#  13423,
#  13424,
#  13425,
#  13426,
#  13427,
#  13428,
#  13429,
#  13430,
#  13431,
#  13432,
#  13433,
#  13434,
#  13435,
#  13436,
#  13437,
#  13438,
#  13439,
#  13440,
#  13441,
#  13442,
#  13443,
#  13444,
#  13445,
#  13446,
#  13447,
#  13448,
#  13449,
#  13450,
#  13451,
#  13452,
#  13453,
#  13454,
#  13455,
#  13456,
#  13457,
#  13458,
#  13459,
#  13460,
#  13461,
#  13462,
#  13463,
#  13464,
#  13465,
#  13466,
#  13467,
#  13468,
#  13469,
#  13470,
#  13471,
#  13472,
#  13473,
#  13474,
#  13475,
#  13476,
#  13477,
#  13478,
#  13479,
#  13480,
#  13481,
#  13482,
#  13483,
#  13484,
#  13485,
#  13486,
#  13487,
#  13488,
#  13489,
#  13490,
#  13491,
#  13492,
#  13493,
#  13494,
#  13495,
#  13496,
#  13497,
#  13498,
#  13499,
#  13500,
#  13501,
#  13502,
#  13503,
#  13504,
#  13505,
#  13506,
#  13507,
#  13508,
#  13509,
#  13510,
#  13511,
#  13512,
#  13513,
#  13514,
#  13515,
#  13516,
#  13517,
#  13518,
#  13519,
#  13520,
#  13521,
#  13522,
#  13523,
#  13524,
#  13525,
#  13526,
#  13527,
#  13528,
#  13529,
#  13530,
#  13531,
#  13532,
#  13533,
#  13534,
#  13535,
#  13536,
#  13537,
#  13538,
#  13539,
#  13540,
#  13541,
#  13542,
#  13543,
#  13544,
#  13545,
#  13546,
#  13547,
#  13548,
#  13549,
#  13550,
#  13551,
#  13552,
#  13553,
#  13554,
#  13555,
#  13556,
#  13557,
#  13558,
#  13559,
#  13560,
#  13561,
#  13562,
#  13563,
#  13564,
#  13565,
#  13566,
#  13567,
#  13568,
#  13569,
#  13570,
#  13571,
#  13572,
#  13573,
#  13574,
#  13575,
#  13576,
#  13577,
#  13578,
#  13579,
#  13580,
#  13581,
#  13582,
#  13583,
#  13584,
#  13585,
#  13586,
#  13587,
#  13588,
#  13589,
#  13590,
#  13591,
#  13592,
#  13593,
#  13594,
#  13595,
#  13596,
#  13597,
#  13598,
#  13599,
#  13600,
#  13601,
#  13602,
#  13603,
#  13604,
#  13605,
#  13606,
#  13607,
#  13608,
#  13609,
#  13610,
#  13611,
#  13612,
#  13613,
#  13614,
#  13615,
#  13616,
#  13617,
#  13618,
#  13619,
#  13620,
#  13621,
#  13622,
#  13623,
#  13624,
#  13625,
#  13626,
#  13627,
#  13628,
#  13629,
#  13630,
#  13631,
#  13632,
#  13633,
#  13634,
#  13635,
#  13636,
#  13637,
#  13638,
#  13639,
#  13640,
#  13641,
#  13642,
#  13643,
#  13644,
#  13645,
#  13646,
#  13647,
#  13648,
#  13649,
#  13650,
#  13651,
#  13652,
#  13653,
#  ...]
